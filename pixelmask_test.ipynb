# %%
from __future__ import print_function
import sys
import time
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
import matplotlib.image as img
image = img.imread("./data/Edge1.jpg")
pokemon = img.imread("./data/pokemon.png")
Edge2 = img.imread("./data/Edge2.jpg")


fig = plt.figure()
fig.add_subplot(2,2,1)
plt.title("Edge1")
plt.imshow(image ,cmap="gray")

fig.add_subplot(2,2,2)
plt.title("pokemon")
plt.imshow(pokemon ,cmap="gray")

fig.add_subplot(2,1,2)
plt.title("Edge2")
plt.imshow(Edge2 ,cmap="gray")

# %% [markdown]
# # Python OpenCV – Filter2D() Function

# %%
# Reading the image
# image = img.imread("./data/Edge1.jpg")
  
# Creating the kernel(2d convolution matrix)
# kernel2 = np.array([[-1, -1, -1],
#                     [-1, 8, -1],
#                     [-1, -1, -1]])

#Pixelmask 1 wihte converting
#Pixelmask 2 blue converting
#Pixelmask 5 blue converting
#Pixelmask 4 black color converting
kernel2 = np.array([
[1, 0, -1],
[2, 0, -2],
[1, 0, -1]])
  
# Applying the filter2D() function
img = cv2.filter2D(src=image, ddepth=-1, kernel=kernel2)
  
# Shoeing the original and output image
cv2.imshow('Original', image)
cv2.imshow('Kernel Blur', img)


  
cv2.waitKey()
cv2.destroyAllWindows()

# %%
print("Before Img:", image.shape)
print("New Img:", img.shape)

fig = plt.figure()
fig.add_subplot(2,2,1)
plt.title("Before Img")
plt.imshow(image ,cmap="gray")

fig.add_subplot(2,2,2)
plt.title("New Img")
plt.imshow(img ,cmap="gray")
# Out:
# Before Img: (246, 351, 3)
# New Img: (246, 351, 3)

# %% [markdown]
# # Python OpenCV – Canny() Function

# %%
# img = Edge2
img = cv2.imread("./data/Edge2.jpg")  # Read image


# Setting parameter values
t_lower = 20  # Lower Threshold
t_upper = 50  # Upper threshold
  
# Applying the Canny Edge filter
edge = cv2.Canny(img, t_lower, t_upper)
  
cv2.imshow('original', img)
cv2.imshow('edge', edge)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
print("Before Img:", image.shape)
print("New Img:", img.shape)

fig = plt.figure()
fig.add_subplot(2,2,1)
plt.title("Before Img")
plt.imshow(img ,cmap="gray")

fig.add_subplot(2,2,2)
plt.title("New Img")
plt.imshow(edge ,cmap="gray")
# Out:
# Before Img: (246, 351, 3)
# New Img: (221, 336, 3)

# %% [markdown]
# Corner Detection with Harris

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img = cv2.imread("./data/building.jpg")
imgGray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
dst = cv2.cornerHarris(imgGray, 2, 3, 0.04)
dst = cv2.dilate(dst, None)

threshold = 0.0006*dst.max()
img[dst>threshold] = [255,0,0]
fig = plt.figure()
fig.set_size_inches(8,8)
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
import cv2
from matplotlib import pyplot as plt

# img = cv2.imread("building.jpg")
img = cv2.imread("./data/building.jpg")
grayImg = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# cornerHarris parameters (grayImg, blockSize, ksize, k)
dst = cv2.cornerHarris(grayImg, 2, 3, 0.04)
dst = cv2.dilate(dst, None)

threshold = 0.0006 * dst.max()
img[dst>threshold] = [0, 0, 255]

fig = plt.figure()
fig.set_size_inches(8,8)
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.show()
